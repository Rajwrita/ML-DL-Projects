# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Categorizing Data:
# <p> The 'id' column is dropped as it has no use in the process. </p>
# <p>Categorical data are variables that contain label values rather than numeric values.The number of possible values is often limited to a fixed set.</p>
#
# ### Splitting Data:
# <p>The data we use is usually split into training data and test data. The training set contains a known output and the model learns on this data in order to be generalized to other data later on. We have the test dataset (or subset) in order to test our model’s prediction on this subset.</p>
#
# #### Finally the Model Function is called.

# %%
def init():
    
    df=pd.read_csv("C://Users//Rajwrita//Desktop//ds//cancer.csv")
    
    
    #Dropping the 'id' column from the dataset
    df=df.drop("id",1)
    df=df.drop("Unnamed: 32",1)
    
    #Mapping M to 1 and B to 0 in the output Label DataFrame
    df['diagnosis']=df['diagnosis'].map({'M':1,'B':0})
    
    
    #Split Data into training and test (70% and 30%)
    train, test = train_test_split(df, test_size = 0.3, random_state=1)
        
    
    #Training Data
    train_x=train.loc[:,'radius_mean' : 'fractal_dimension_worst']
    train_y=train.loc[:,['diagnosis']]
    
    #Testing Data
    test_x=test.loc[:,'radius_mean' : 'fractal_dimension_worst']
    test_y=test.loc[:,['diagnosis']]
    
    #Converting Traing and Test Data to numpy array
    train_x=np.asarray(train_x)
    train_y=np.asarray(train_y)
    test_x=np.asarray(test_x)
    test_y=np.asarray(test_y)
    
    #Calling the model function to train a Logistic Regression Model on Training Data
    d= model(train_x.T, train_y.T, num_of_iterations=10000, alpha=0.000001)
    
        
    costs=d["costs"]
    w=d["w"]
    b=d["b"]
    
    #Drawing the plot between cost and number of iterations
    plt.plot(costs)
    plt.title("Cost vs #Iterations")
    plt.xlabel("Number of Iterations ( * 10)")
    plt.ylabel("Cost")
    
    
    #Now, calculating the accuracy on Training and Test Data
    Y_prediction_train = predict(train_x.T, w, b)
    Y_prediction_test = predict(test_x.T, w, b)
    
    
    
    print("\nTrain accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - train_y.T)) * 100))
    
    print("\nTest accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_test - test_y.T)) * 100))

# %%
#Function to initialize the weights and bias
def initialize(m):
    
    w = np.zeros((m,1))
    b = 0
    
    return w , b

# %%
#Function to calculate sigmoid of x    
def sigmoid(X):
    return 1/(1 + np.exp(- X))

# %%
#Function for doing forward and back propogation
def propogate(X, Y, w, b):
    
    m = X.shape[1] #Number of training examples

    #Forward Propogation, calculating the cost
    Z = np.dot(w.T, X) + b;    
    A = sigmoid(Z)
    cost= -(1/m) * np.sum(Y * np.log(A) + (1-Y) * np.log(1-A))
    
    #Back Propogation , calculating the gradients
    dw = (1/m)* np.dot(X, (A-Y).T)
    db = (1/m)* np.sum(A-Y)
    
    grads= {"dw" : dw, "db" : db}
    
    return grads, cost

# %%
#Function for performing Grdient Descent
def optimize(X, Y, w, b, num_of_iterations, alpha):
    
    costs=[] 
    
    for i in range(num_of_iterations):
 
        grads, cost = propogate(X, Y, w, b)
        
        dw = grads["dw"]
        db = grads["db"]
        
        w = w - alpha * dw
        b = b - alpha * db
        
        #Storing tthe cost at interval of every 10 iterations
        if i% 10 == 0:
            costs.append(cost)
            print("cost after %i iteration : %f" % (i, cost))
            
            
    parameters = {"w":w, "b":b}
    grads = {"dw":dw, "db":db}
    
    
    return parameters, grads, costs

# %%
#Function for doing the predictions on the data set (mapping probabilities to 0 or 1)
def predict(X, w, b):
    
    m = X.shape[1] #Number of training examples
    
    y_prediction =  np.zeros((1,m))
    
    w = w.reshape(X.shape[0], 1)
    
    A=sigmoid(np.dot(w.T, X)+b)
    
    
    for i in range(A.shape[1]):
        
        if(A[0,i]<0.5):
            y_prediction[0,i]=0
        else:
            y_prediction[0,i]=1
            
    
    return y_prediction

# %%
#Function for calculating the Logistic Regression Model
def model(Xtrain, Ytrain, num_of_iterations, alpha):
    
    dim = Xtrain.shape[0] #Number of features
    
    w,b = initialize(dim)
    
    parameters, grads, costs = optimize(Xtrain, Ytrain, w, b, num_of_iterations, alpha) 
    
    w = parameters["w"]
    b = parameters["b"]
        
    
    d={"w":w, "b":b, "costs": costs}
    
    return d

# %%
init()
# Out:
# cost after 0 iteration : 0.693147
# cost after 10 iteration : 0.671487
# cost after 20 iteration : 0.664807
# cost after 30 iteration : 0.658434
# cost after 40 iteration : 0.652346
# cost after 50 iteration : 0.646521
# cost after 60 iteration : 0.640940
# cost after 70 iteration : 0.635585
# cost after 80 iteration : 0.630439
# cost after 90 iteration : 0.625489
# cost after 100 iteration : 0.620721
# cost after 110 iteration : 0.616123
# cost after 120 iteration : 0.611684
# cost after 130 iteration : 0.607394
# cost after 140 iteration : 0.603243
# cost after 150 iteration : 0.599223
# cost after 160 iteration : 0.595328
# cost after 170 iteration : 0.591549
# cost after 180 iteration : 0.587880
# cost after 190 iteration : 0.584316
# cost after 200 iteration : 0.580850
# cost after 210 iteration : 0.577478
# cost after 220 iteration : 0.574196
# cost after 230 iteration : 0.570998
# cost after 240 iteration : 0.567881
# cost after 250 iteration : 0.564841
# cost after 260 iteration : 0.561875
# cost after 270 iteration : 0.558979
# cost after 280 iteration : 0.556150
# cost after 290 iteration : 0.553386
# cost after 300 iteration : 0.550683
# cost after 310 iteration : 0.548040
# cost after 320 iteration : 0.545453
# cost after 330 iteration : 0.542921
# cost after 340 iteration : 0.540442
# cost after 350 iteration : 0.538013
# cost after 360 iteration : 0.535633
# cost after 370 iteration : 0.533300
# cost after 380 iteration : 0.531012
# cost after 390 iteration : 0.528768
# cost after 400 iteration : 0.526566
# cost after 410 iteration : 0.524405
# cost after 420 iteration : 0.522284
# cost after 430 iteration : 0.520200
# cost after 440 iteration : 0.518154
# cost after 450 iteration : 0.516143
# cost after 460 iteration : 0.514167
# cost after 470 iteration : 0.512224
# cost after 480 iteration : 0.510314
# cost after 490 iteration : 0.508435
# cost after 500 iteration : 0.506587
# cost after 510 iteration : 0.504769
# cost after 520 iteration : 0.502980
# cost after 530 iteration : 0.501219
# cost after 540 iteration : 0.499485
# cost after 550 iteration : 0.497777
# cost after 560 iteration : 0.496096
# cost after 570 iteration : 0.494440
# cost after 580 iteration : 0.492808
# cost after 590 iteration : 0.491199
# cost after 600 iteration : 0.489614
# cost after 610 iteration : 0.488052
# cost after 620 iteration : 0.486512
# cost after 630 iteration : 0.484993
# cost after 640 iteration : 0.483495
# cost after 650 iteration : 0.482018
# cost after 660 iteration : 0.480560
# cost after 670 iteration : 0.479122
# cost after 680 iteration : 0.477703
# cost after 690 iteration : 0.476302
# cost after 700 iteration : 0.474920
# cost after 710 iteration : 0.473555
# cost after 720 iteration : 0.472208
# cost after 730 iteration : 0.470878
# cost after 740 iteration : 0.469564
# cost after 750 iteration : 0.468266
# cost after 760 iteration : 0.466984
# cost after 770 iteration : 0.465718
# cost after 780 iteration : 0.464467
# cost after 790 iteration : 0.463230
# cost after 800 iteration : 0.462008
# cost after 810 iteration : 0.460801
# cost after 820 iteration : 0.459607
# cost after 830 iteration : 0.458427
# cost after 840 iteration : 0.457260
# cost after 850 iteration : 0.456106
# cost after 860 iteration : 0.454965
# cost after 870 iteration : 0.453837
# cost after 880 iteration : 0.452721
# cost after 890 iteration : 0.451617
# cost after 900 iteration : 0.450525
# cost after 910 iteration : 0.449445
# cost after 920 iteration : 0.448376
# cost after 930 iteration : 0.447318
# cost after 940 iteration : 0.446272
# cost after 950 iteration : 0.445236
# cost after 960 iteration : 0.444210
# cost after 970 iteration : 0.443195
# cost after 980 iteration : 0.442191
# cost after 990 iteration : 0.441196
# cost after 1000 iteration : 0.440211
# cost after 1010 iteration : 0.439236
# cost after 1020 iteration : 0.438270
# cost after 1030 iteration : 0.437314
# cost after 1040 iteration : 0.436366
# cost after 1050 iteration : 0.435428
# cost after 1060 iteration : 0.434499
# cost after 1070 iteration : 0.433578
# cost after 1080 iteration : 0.432666
# cost after 1090 iteration : 0.431763
# cost after 1100 iteration : 0.430868
# cost after 1110 iteration : 0.429981
# cost after 1120 iteration : 0.429101
# cost after 1130 iteration : 0.428230
# cost after 1140 iteration : 0.427367
# cost after 1150 iteration : 0.426511
# cost after 1160 iteration : 0.425663
# cost after 1170 iteration : 0.424822
# cost after 1180 iteration : 0.423989
# cost after 1190 iteration : 0.423162
# cost after 1200 iteration : 0.422343
# cost after 1210 iteration : 0.421531
# cost after 1220 iteration : 0.420725
# cost after 1230 iteration : 0.419927
# cost after 1240 iteration : 0.419135
# cost after 1250 iteration : 0.418349
# cost after 1260 iteration : 0.417570
# cost after 1270 iteration : 0.416798
# cost after 1280 iteration : 0.416031
# cost after 1290 iteration : 0.415271
# cost after 1300 iteration : 0.414517
# cost after 1310 iteration : 0.413769
# cost after 1320 iteration : 0.413027
# cost after 1330 iteration : 0.412290
# cost after 1340 iteration : 0.411560
# cost after 1350 iteration : 0.410835
# cost after 1360 iteration : 0.410116
# cost after 1370 iteration : 0.409402
# cost after 1380 iteration : 0.408694
# cost after 1390 iteration : 0.407991
# cost after 1400 iteration : 0.407293
# cost after 1410 iteration : 0.406601
# cost after 1420 iteration : 0.405914
# cost after 1430 iteration : 0.405232
# cost after 1440 iteration : 0.404554
# cost after 1450 iteration : 0.403882
# cost after 1460 iteration : 0.403215
# cost after 1470 iteration : 0.402553
# cost after 1480 iteration : 0.401895
# cost after 1490 iteration : 0.401242
# cost after 1500 iteration : 0.400594
# cost after 2360 iteration : 0.357627
# cost after 2370 iteration : 0.357238
# cost after 2380 iteration : 0.356851
# cost after 2390 iteration : 0.356465
# cost after 2400 iteration : 0.356082
# cost after 2410 iteration : 0.355700
# cost after 2420 iteration : 0.355321
# cost after 2430 iteration : 0.354943
# cost after 2440 iteration : 0.354567
# cost after 2450 iteration : 0.354193
# cost after 2460 iteration : 0.353820
# cost after 2470 iteration : 0.353449
# cost after 2480 iteration : 0.353081
# cost after 2490 iteration : 0.352714
# cost after 2500 iteration : 0.352348
# cost after 2510 iteration : 0.351985
# cost after 2520 iteration : 0.351623
# cost after 2530 iteration : 0.351262
# cost after 2540 iteration : 0.350904
# cost after 2550 iteration : 0.350547
# cost after 2560 iteration : 0.350192
# cost after 2570 iteration : 0.349838
# cost after 2580 iteration : 0.349486
# cost after 2590 iteration : 0.349136
# cost after 2600 iteration : 0.348788
# cost after 2610 iteration : 0.348440
# cost after 2620 iteration : 0.348095
# cost after 2630 iteration : 0.347751
# cost after 2640 iteration : 0.347409
# cost after 2650 iteration : 0.347068
# cost after 2660 iteration : 0.346729
# cost after 2670 iteration : 0.346391
# cost after 2680 iteration : 0.346055
# cost after 2690 iteration : 0.345721
# cost after 2700 iteration : 0.345387
# cost after 2710 iteration : 0.345056
# cost after 2720 iteration : 0.344726
# cost after 2730 iteration : 0.344397
# cost after 2740 iteration : 0.344070
# cost after 2750 iteration : 0.343744
# cost after 2760 iteration : 0.343420
# cost after 2770 iteration : 0.343097
# cost after 2780 iteration : 0.342775
# cost after 2790 iteration : 0.342455
# cost after 2800 iteration : 0.342137
# cost after 2810 iteration : 0.341819
# cost after 2820 iteration : 0.341504
# cost after 2830 iteration : 0.341189
# cost after 2840 iteration : 0.340876
# cost after 2850 iteration : 0.340564
# cost after 2860 iteration : 0.340254
# cost after 2870 iteration : 0.339945
# cost after 2880 iteration : 0.339637
# cost after 2890 iteration : 0.339331
# cost after 2900 iteration : 0.339025
# cost after 2910 iteration : 0.338722
# cost after 2920 iteration : 0.338419
# cost after 2930 iteration : 0.338118
# cost after 2940 iteration : 0.337818
# cost after 2950 iteration : 0.337519
# cost after 2960 iteration : 0.337222
# cost after 2970 iteration : 0.336926
# cost after 2980 iteration : 0.336631
# cost after 2990 iteration : 0.336337
# cost after 3000 iteration : 0.336045
# cost after 3010 iteration : 0.335753
# cost after 3020 iteration : 0.335463
# cost after 3030 iteration : 0.335175
# cost after 3040 iteration : 0.334887
# cost after 3050 iteration : 0.334601
# cost after 3060 iteration : 0.334315
# cost after 3070 iteration : 0.334031
# cost after 3080 iteration : 0.333748
# cost after 3090 iteration : 0.333467
# cost after 3100 iteration : 0.333186
# cost after 3110 iteration : 0.332907
# cost after 3120 iteration : 0.332628
# cost after 3130 iteration : 0.332351
# cost after 3140 iteration : 0.332075
# cost after 3150 iteration : 0.331800
# cost after 3160 iteration : 0.331526
# cost after 3170 iteration : 0.331254
# cost after 3180 iteration : 0.330982
# cost after 3190 iteration : 0.330712
# cost after 3200 iteration : 0.330442
# cost after 4920 iteration : 0.296129
# cost after 4930 iteration : 0.295982
# cost after 4940 iteration : 0.295834
# cost after 4950 iteration : 0.295688
# cost after 4960 iteration : 0.295542
# cost after 4970 iteration : 0.295396
# cost after 4980 iteration : 0.295251
# cost after 4990 iteration : 0.295106
# cost after 5000 iteration : 0.294961
# cost after 5010 iteration : 0.294817
# cost after 5020 iteration : 0.294674
# cost after 5030 iteration : 0.294531
# cost after 5040 iteration : 0.294388
# cost after 5050 iteration : 0.294245
# cost after 5060 iteration : 0.294104
# cost after 5070 iteration : 0.293962
# cost after 5080 iteration : 0.293821
# cost after 5090 iteration : 0.293680
# cost after 5100 iteration : 0.293540
# cost after 5110 iteration : 0.293400
# cost after 5120 iteration : 0.293261
# cost after 5130 iteration : 0.293122
# cost after 5140 iteration : 0.292983
# cost after 5150 iteration : 0.292845
# cost after 5160 iteration : 0.292708
# cost after 5170 iteration : 0.292570
# cost after 5180 iteration : 0.292433
# cost after 5190 iteration : 0.292297
# cost after 5200 iteration : 0.292160
# cost after 5210 iteration : 0.292025
# cost after 5220 iteration : 0.291889
# cost after 5230 iteration : 0.291754
# cost after 5240 iteration : 0.291620
# cost after 5250 iteration : 0.291485
# cost after 5260 iteration : 0.291352
# cost after 5270 iteration : 0.291218
# cost after 5280 iteration : 0.291085
# cost after 5290 iteration : 0.290952
# cost after 5300 iteration : 0.290820
# cost after 5310 iteration : 0.290688
# cost after 5320 iteration : 0.290557
# cost after 5330 iteration : 0.290425
# cost after 5340 iteration : 0.290295
# cost after 5350 iteration : 0.290164
# cost after 5360 iteration : 0.290034
# cost after 5370 iteration : 0.289904
# cost after 5380 iteration : 0.289775
# cost after 5390 iteration : 0.289646
# cost after 5400 iteration : 0.289518
# cost after 5410 iteration : 0.289389
# cost after 5420 iteration : 0.289261
# cost after 5430 iteration : 0.289134
# cost after 5440 iteration : 0.289007
# cost after 5450 iteration : 0.288880
# cost after 5460 iteration : 0.288753
# cost after 5470 iteration : 0.288627
# cost after 5480 iteration : 0.288502
# cost after 5490 iteration : 0.288376
# cost after 5500 iteration : 0.288251
# cost after 5510 iteration : 0.288126
# cost after 5520 iteration : 0.288002
# cost after 5530 iteration : 0.287878
# cost after 5540 iteration : 0.287754
# cost after 5550 iteration : 0.287631
# cost after 5560 iteration : 0.287508
# cost after 5570 iteration : 0.287385
# cost after 5580 iteration : 0.287263
# cost after 5590 iteration : 0.287141
# cost after 5600 iteration : 0.287019
# cost after 5610 iteration : 0.286898
# cost after 5620 iteration : 0.286777
# cost after 5630 iteration : 0.286656
# cost after 5640 iteration : 0.286536
# cost after 5650 iteration : 0.286416
# cost after 5660 iteration : 0.286296
# cost after 5670 iteration : 0.286177
# cost after 5680 iteration : 0.286058
# cost after 5690 iteration : 0.285939
# cost after 5700 iteration : 0.285821
# cost after 5710 iteration : 0.285703
# cost after 5720 iteration : 0.285585
# cost after 5730 iteration : 0.285467
# cost after 5740 iteration : 0.285350
# cost after 5750 iteration : 0.285233
# cost after 5760 iteration : 0.285117
# cost after 5770 iteration : 0.285001
# cost after 5780 iteration : 0.284885
# cost after 5790 iteration : 0.284769
# cost after 5800 iteration : 0.284654
# cost after 5810 iteration : 0.284539
# cost after 5820 iteration : 0.284424
# cost after 5830 iteration : 0.284310
# cost after 5840 iteration : 0.284196
# cost after 5850 iteration : 0.284082
# cost after 5860 iteration : 0.283969
# cost after 5870 iteration : 0.283855
# cost after 5880 iteration : 0.283743
# cost after 5890 iteration : 0.283630
# cost after 5900 iteration : 0.283518
# cost after 5910 iteration : 0.283406
# cost after 5920 iteration : 0.283294
# cost after 5930 iteration : 0.283183
# cost after 5940 iteration : 0.283072
# cost after 5950 iteration : 0.282961
# cost after 5960 iteration : 0.282850
# cost after 5970 iteration : 0.282740
# cost after 5980 iteration : 0.282630
# cost after 5990 iteration : 0.282520
# cost after 6000 iteration : 0.282411
# cost after 6010 iteration : 0.282302
# cost after 6020 iteration : 0.282193
# cost after 6030 iteration : 0.282084
# cost after 6040 iteration : 0.281976
# cost after 6050 iteration : 0.281868
# cost after 6060 iteration : 0.281760
# cost after 6070 iteration : 0.281653
# cost after 6080 iteration : 0.281546
# cost after 6090 iteration : 0.281439
# cost after 6100 iteration : 0.281332
# cost after 6110 iteration : 0.281226
# cost after 6120 iteration : 0.281120
# cost after 6130 iteration : 0.281014
# cost after 6140 iteration : 0.280908
# cost after 6150 iteration : 0.280803
# cost after 6160 iteration : 0.280698
# cost after 6170 iteration : 0.280593
# cost after 6180 iteration : 0.280489
# cost after 6190 iteration : 0.280384
# cost after 6200 iteration : 0.280280
# cost after 6210 iteration : 0.280177
# cost after 6220 iteration : 0.280073
# cost after 6230 iteration : 0.279970
# cost after 6240 iteration : 0.279867
# cost after 6250 iteration : 0.279764
# cost after 6260 iteration : 0.279662
# cost after 6270 iteration : 0.279560
# cost after 6280 iteration : 0.279458
# cost after 6290 iteration : 0.279356
# cost after 6300 iteration : 0.279255
# cost after 6310 iteration : 0.279154
# cost after 6320 iteration : 0.279053
# cost after 6330 iteration : 0.278952
# cost after 6340 iteration : 0.278852
# cost after 6350 iteration : 0.278751
# cost after 6360 iteration : 0.278651
# cost after 6370 iteration : 0.278552
# cost after 6380 iteration : 0.278452
# cost after 6390 iteration : 0.278353
# cost after 6400 iteration : 0.278254
# cost after 6410 iteration : 0.278155
# cost after 6420 iteration : 0.278057
# cost after 6430 iteration : 0.277959
# cost after 6440 iteration : 0.277861
# cost after 6450 iteration : 0.277763
# cost after 6460 iteration : 0.277665
# cost after 6470 iteration : 0.277568
# cost after 6480 iteration : 0.277471
# cost after 6490 iteration : 0.277374
# cost after 6500 iteration : 0.277278
# cost after 6510 iteration : 0.277181
# cost after 6520 iteration : 0.277085
# cost after 6530 iteration : 0.276989
# cost after 6540 iteration : 0.276893
# cost after 6550 iteration : 0.276798
# cost after 6560 iteration : 0.276703
# cost after 6570 iteration : 0.276608
# cost after 6580 iteration : 0.276513
# cost after 6590 iteration : 0.276418
# cost after 6600 iteration : 0.276324
# cost after 6610 iteration : 0.276230
# cost after 6620 iteration : 0.276136
# cost after 6630 iteration : 0.276042
# cost after 6640 iteration : 0.275949
# cost after 6650 iteration : 0.275856
# cost after 6660 iteration : 0.275763
# cost after 6670 iteration : 0.275670
# cost after 6680 iteration : 0.275577
# cost after 6690 iteration : 0.275485
# cost after 6700 iteration : 0.275393
# cost after 6710 iteration : 0.275301
# cost after 6720 iteration : 0.275209
# cost after 6730 iteration : 0.275118
# cost after 6740 iteration : 0.275027
# cost after 6750 iteration : 0.274936
# cost after 6760 iteration : 0.274845
# cost after 6770 iteration : 0.274754
# cost after 6780 iteration : 0.274664
# cost after 6790 iteration : 0.274573
# cost after 6800 iteration : 0.274483
# cost after 6810 iteration : 0.274394
# cost after 6820 iteration : 0.274304
# cost after 6830 iteration : 0.274215
# cost after 6840 iteration : 0.274125
# cost after 6850 iteration : 0.274036
# cost after 6860 iteration : 0.273948
# cost after 6870 iteration : 0.273859
# cost after 6880 iteration : 0.273771
# cost after 6890 iteration : 0.273682
# cost after 6900 iteration : 0.273594
# cost after 6910 iteration : 0.273507
# cost after 6920 iteration : 0.273419
# cost after 6930 iteration : 0.273332
# cost after 6940 iteration : 0.273245
# cost after 6950 iteration : 0.273158
# cost after 6960 iteration : 0.273071
# cost after 6970 iteration : 0.272984
# cost after 6980 iteration : 0.272898
# cost after 6990 iteration : 0.272812
# cost after 7000 iteration : 0.272726
# cost after 7010 iteration : 0.272640
# cost after 7020 iteration : 0.272554
# cost after 7030 iteration : 0.272469
# cost after 7040 iteration : 0.272383
# cost after 7050 iteration : 0.272298
# cost after 7060 iteration : 0.272214
# cost after 7070 iteration : 0.272129
# cost after 7080 iteration : 0.272044
# cost after 7090 iteration : 0.271960
# cost after 7100 iteration : 0.271876
# cost after 7110 iteration : 0.271792
# cost after 7120 iteration : 0.271708
# cost after 7130 iteration : 0.271625
# cost after 7140 iteration : 0.271541
# cost after 7150 iteration : 0.271458
# cost after 7160 iteration : 0.271375
# cost after 7170 iteration : 0.271292
# cost after 7180 iteration : 0.271210
# cost after 7190 iteration : 0.271127
# cost after 7200 iteration : 0.271045
# cost after 7210 iteration : 0.270963
# cost after 7220 iteration : 0.270881
# cost after 7230 iteration : 0.270799
# cost after 7240 iteration : 0.270718
# cost after 7250 iteration : 0.270636
# cost after 7260 iteration : 0.270555
# cost after 7270 iteration : 0.270474
# cost after 7280 iteration : 0.270393
# cost after 7290 iteration : 0.270312
# cost after 7300 iteration : 0.270232
# cost after 7310 iteration : 0.270152
# cost after 7320 iteration : 0.270071
# cost after 7330 iteration : 0.269991
# cost after 7340 iteration : 0.269912
# cost after 7350 iteration : 0.269832
# cost after 7360 iteration : 0.269752
# cost after 7370 iteration : 0.269673
# cost after 7380 iteration : 0.269594
# cost after 7390 iteration : 0.269515
# cost after 7400 iteration : 0.269436
# cost after 7410 iteration : 0.269358
# cost after 7420 iteration : 0.269279
# cost after 7430 iteration : 0.269201
# cost after 7440 iteration : 0.269123
# cost after 7450 iteration : 0.269045
# cost after 7460 iteration : 0.268967
# cost after 7470 iteration : 0.268889
# cost after 7480 iteration : 0.268812
# cost after 7490 iteration : 0.268734
# cost after 7500 iteration : 0.268657
# cost after 7510 iteration : 0.268580
# cost after 7520 iteration : 0.268503
# cost after 7530 iteration : 0.268427
# cost after 7540 iteration : 0.268350
# cost after 7550 iteration : 0.268274
# cost after 7560 iteration : 0.268198
# cost after 7570 iteration : 0.268122
# cost after 7580 iteration : 0.268046
# cost after 7590 iteration : 0.267970
# cost after 7600 iteration : 0.267895
# cost after 7610 iteration : 0.267819
# cost after 7620 iteration : 0.267744
# cost after 7630 iteration : 0.267669
# cost after 7640 iteration : 0.267594
# cost after 7650 iteration : 0.267519
# cost after 7660 iteration : 0.267444
# cost after 7670 iteration : 0.267370
# cost after 7680 iteration : 0.267296
# cost after 7690 iteration : 0.267222
# cost after 7700 iteration : 0.267148
# cost after 7710 iteration : 0.267074
# cost after 7720 iteration : 0.267000
# cost after 7730 iteration : 0.266926
# cost after 7740 iteration : 0.266853
# cost after 7750 iteration : 0.266780
# cost after 7760 iteration : 0.266707
# cost after 7770 iteration : 0.266634
# cost after 7780 iteration : 0.266561
# cost after 7790 iteration : 0.266488
# cost after 7800 iteration : 0.266416
# cost after 7810 iteration : 0.266343
# cost after 7820 iteration : 0.266271
# cost after 7830 iteration : 0.266199
# cost after 7840 iteration : 0.266127
# cost after 7850 iteration : 0.266055
# cost after 7860 iteration : 0.265984
# cost after 7870 iteration : 0.265912
# cost after 7880 iteration : 0.265841
# cost after 7890 iteration : 0.265770
# cost after 7900 iteration : 0.265699
# cost after 7910 iteration : 0.265628
# cost after 7920 iteration : 0.265557
# cost after 7930 iteration : 0.265486
# cost after 7940 iteration : 0.265416
# cost after 7950 iteration : 0.265345
# cost after 7960 iteration : 0.265275
# cost after 7970 iteration : 0.265205
# cost after 7980 iteration : 0.265135
# cost after 7990 iteration : 0.265065
# cost after 8000 iteration : 0.264996
# cost after 8010 iteration : 0.264926
# cost after 8020 iteration : 0.264857
# cost after 8030 iteration : 0.264787
# cost after 8040 iteration : 0.264718
# cost after 8050 iteration : 0.264649
# cost after 8060 iteration : 0.264580
# cost after 8070 iteration : 0.264512
# cost after 8080 iteration : 0.264443
# cost after 8090 iteration : 0.264375
# cost after 8100 iteration : 0.264306
# cost after 8110 iteration : 0.264238
# cost after 8120 iteration : 0.264170
# cost after 8130 iteration : 0.264102
# cost after 8140 iteration : 0.264035
# cost after 8150 iteration : 0.263967
# cost after 8160 iteration : 0.263899
# cost after 8170 iteration : 0.263832
# cost after 8180 iteration : 0.263765
# cost after 8190 iteration : 0.263698
# cost after 8200 iteration : 0.263631
# cost after 8210 iteration : 0.263564
# cost after 8220 iteration : 0.263497
# cost after 8230 iteration : 0.263430
# cost after 8240 iteration : 0.263364
# cost after 8250 iteration : 0.263298
# cost after 8260 iteration : 0.263231
# cost after 8270 iteration : 0.263165
# cost after 8280 iteration : 0.263099
# cost after 8290 iteration : 0.263033
# cost after 8300 iteration : 0.262968
# cost after 8310 iteration : 0.262902
# cost after 8320 iteration : 0.262837
# cost after 8330 iteration : 0.262771
# cost after 8340 iteration : 0.262706
# cost after 8350 iteration : 0.262641
# cost after 8360 iteration : 0.262576
# cost after 8370 iteration : 0.262511
# cost after 8380 iteration : 0.262446
# cost after 8390 iteration : 0.262382
# cost after 8400 iteration : 0.262317
# cost after 8410 iteration : 0.262253
# cost after 8420 iteration : 0.262189
# cost after 8430 iteration : 0.262125
# cost after 8440 iteration : 0.262061
# cost after 8450 iteration : 0.261997
# cost after 8460 iteration : 0.261933
# cost after 8470 iteration : 0.261869
# cost after 8480 iteration : 0.261806
# cost after 8490 iteration : 0.261742
# cost after 8500 iteration : 0.261679
# cost after 8510 iteration : 0.261616
# cost after 8520 iteration : 0.261553
# cost after 8530 iteration : 0.261490
# cost after 8540 iteration : 0.261427
# cost after 8550 iteration : 0.261365
# cost after 8560 iteration : 0.261302
# cost after 8570 iteration : 0.261240
# cost after 8580 iteration : 0.261177
# cost after 8590 iteration : 0.261115
# cost after 8600 iteration : 0.261053
# cost after 8610 iteration : 0.260991
# cost after 8620 iteration : 0.260929
# cost after 8630 iteration : 0.260867
# cost after 8640 iteration : 0.260806
# cost after 8650 iteration : 0.260744
# cost after 8660 iteration : 0.260683
# cost after 8670 iteration : 0.260621
# cost after 8680 iteration : 0.260560
# cost after 8690 iteration : 0.260499
# cost after 8700 iteration : 0.260438
# cost after 8710 iteration : 0.260377
# cost after 8720 iteration : 0.260316
# cost after 8730 iteration : 0.260256
# cost after 8740 iteration : 0.260195
# cost after 8750 iteration : 0.260135
# cost after 8760 iteration : 0.260074
# cost after 8770 iteration : 0.260014
# cost after 8780 iteration : 0.259954
# cost after 8790 iteration : 0.259894
# cost after 8800 iteration : 0.259834
# cost after 8810 iteration : 0.259774
# cost after 8820 iteration : 0.259715
# cost after 8830 iteration : 0.259655
# cost after 8840 iteration : 0.259596
# cost after 8850 iteration : 0.259536
# cost after 8860 iteration : 0.259477
# cost after 8870 iteration : 0.259418
# cost after 8880 iteration : 0.259359
# cost after 8890 iteration : 0.259300
# cost after 8900 iteration : 0.259241
# cost after 8910 iteration : 0.259182
# cost after 8920 iteration : 0.259124
# cost after 8930 iteration : 0.259065
# cost after 8940 iteration : 0.259007
# cost after 8950 iteration : 0.258949
# cost after 8960 iteration : 0.258890
# cost after 8970 iteration : 0.258832
# cost after 8980 iteration : 0.258774
# cost after 8990 iteration : 0.258717
# cost after 9000 iteration : 0.258659
# cost after 9010 iteration : 0.258601
# cost after 9020 iteration : 0.258543
# cost after 9030 iteration : 0.258486
# cost after 9040 iteration : 0.258429
# cost after 9050 iteration : 0.258371
# cost after 9060 iteration : 0.258314
# cost after 9070 iteration : 0.258257
# cost after 9080 iteration : 0.258200
# cost after 9090 iteration : 0.258143
# cost after 9100 iteration : 0.258086
# cost after 9110 iteration : 0.258030
# cost after 9120 iteration : 0.257973
# cost after 9130 iteration : 0.257917
# cost after 9140 iteration : 0.257860
# cost after 9150 iteration : 0.257804
# cost after 9160 iteration : 0.257748
# cost after 9170 iteration : 0.257692
# cost after 9180 iteration : 0.257636
# cost after 9190 iteration : 0.257580
# cost after 9200 iteration : 0.257524
# cost after 9210 iteration : 0.257468
# cost after 9220 iteration : 0.257413
# cost after 9230 iteration : 0.257357
# cost after 9240 iteration : 0.257302
# cost after 9250 iteration : 0.257247
# cost after 9260 iteration : 0.257191
# cost after 9270 iteration : 0.257136
# cost after 9280 iteration : 0.257081
# cost after 9290 iteration : 0.257026
# cost after 9300 iteration : 0.256971
# cost after 9310 iteration : 0.256917
# cost after 9320 iteration : 0.256862
# cost after 9330 iteration : 0.256807
# cost after 9340 iteration : 0.256753
# cost after 9350 iteration : 0.256699
# cost after 9360 iteration : 0.256644
# cost after 9370 iteration : 0.256590
# cost after 9380 iteration : 0.256536
# cost after 9390 iteration : 0.256482
# cost after 9400 iteration : 0.256428
# cost after 9410 iteration : 0.256374
# cost after 9420 iteration : 0.256321
# cost after 9430 iteration : 0.256267
# cost after 9440 iteration : 0.256213
# cost after 9450 iteration : 0.256160
# cost after 9460 iteration : 0.256107
# cost after 9470 iteration : 0.256053
# cost after 9480 iteration : 0.256000
# cost after 9490 iteration : 0.255947
# cost after 9500 iteration : 0.255894
# cost after 9510 iteration : 0.255841
# cost after 9520 iteration : 0.255788
# cost after 9530 iteration : 0.255735
# cost after 9540 iteration : 0.255683
# cost after 9550 iteration : 0.255630
# cost after 9560 iteration : 0.255578
# cost after 9570 iteration : 0.255525
# cost after 9580 iteration : 0.255473
# cost after 9590 iteration : 0.255421
# cost after 9600 iteration : 0.255369
# cost after 9610 iteration : 0.255317
# cost after 9620 iteration : 0.255265
# cost after 9630 iteration : 0.255213
# cost after 9640 iteration : 0.255161
# cost after 9650 iteration : 0.255109
# cost after 9660 iteration : 0.255058
# cost after 9670 iteration : 0.255006
# cost after 9680 iteration : 0.254955
# cost after 9690 iteration : 0.254903
# cost after 9700 iteration : 0.254852
# cost after 9710 iteration : 0.254801
# cost after 9720 iteration : 0.254750
# cost after 9730 iteration : 0.254699
# cost after 9740 iteration : 0.254648
# cost after 9750 iteration : 0.254597
# cost after 9760 iteration : 0.254546
# cost after 9770 iteration : 0.254495
# cost after 9780 iteration : 0.254445
# cost after 9790 iteration : 0.254394
# cost after 9800 iteration : 0.254344
# cost after 9810 iteration : 0.254293
# cost after 9820 iteration : 0.254243
# cost after 9830 iteration : 0.254193
# cost after 9840 iteration : 0.254143
# cost after 9850 iteration : 0.254093
# cost after 9860 iteration : 0.254043
# cost after 9870 iteration : 0.253993
# cost after 9880 iteration : 0.253943
# cost after 9890 iteration : 0.253893
# cost after 9900 iteration : 0.253844
# cost after 9910 iteration : 0.253794
# cost after 9920 iteration : 0.253745
# cost after 9930 iteration : 0.253695
# cost after 9940 iteration : 0.253646
# cost after 9950 iteration : 0.253597
# cost after 9960 iteration : 0.253548
# cost after 9970 iteration : 0.253499
# cost after 9980 iteration : 0.253450
# cost after 9990 iteration : 0.253401
#
# Train accuracy: 91.95979899497488 %
#
# Test accuracy: 91.81286549707602 %
